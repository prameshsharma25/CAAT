# %%
import pickle

with open("xcl1_out/xcl1_all_rank_001_alphafold2_model_2_seed_000.pickle", "rb") as f:
    data = pickle.load(f)

type(data), getattr(data, "keys", lambda: None)()
# Out:
# (dict,
#  dict_keys(['distogram', 'experimentally_resolved', 'masked_msa', 'mean_plddt', 'plddt', 'predicted_lddt', 'ranking_confidence', 'structure_module', 'tol', 'representations']))

# %%
data['distogram']['logits'].shape
# Out:
# (69, 69, 64)

# %%
import numpy as np

distogram = np.load('xcl1_distograms/model_1_recycle_0_main_loop_1_distogram.npz')

# %%
distogram['logits']
# Out:
# array([[[ 18.256147 ,  -4.48173  , -17.645182 , ..., -23.536545 ,
#          -27.810987 , -12.384385 ],
#         [  8.889317 ,  -1.4647429, -10.975309 , ...,  -7.976941 ,
#          -11.870502 ,  -2.6165774],
#         [  9.183842 ,  -1.0223162, -11.169196 , ..., -10.25746  ,
#          -13.825022 ,  -2.3513956],
#         ...,
#         [  2.9214811,  -5.8818254, -16.56784  , ...,  -8.269012 ,
#          -12.249809 ,  -2.1330106],
#         [  1.9919369,  -6.3089066, -17.070168 , ...,  -9.0014515,
#          -12.81184  ,  -2.1256642],
#         [  2.6501658,  -6.3719277, -15.9188385, ...,  -8.642036 ,
#          -12.7761345,  -2.8220592]],
#
#        [[  8.889317 ,  -1.4647429, -10.975309 , ...,  -7.976941 ,
#          -11.870502 ,  -2.6165774],
#         [ 18.654617 ,  -4.4014177, -18.914082 , ..., -26.117064 ,
#          -29.347672 , -13.074538 ],
#         [  9.596279 ,  -1.3311628, -11.359992 , ...,  -6.9763308,
#          -10.617752 ,  -1.6507655],
#         ...,
# ...
